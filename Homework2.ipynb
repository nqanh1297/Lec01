# %%
a=int(input())
b=int(input())
s=a*b
p=(a+b)*2
print(s)
print(p)
# Out:
#  2
#  5
# 10
# 14

# %%
import math
r=float(input())
s=(r**2)*math.pi
c=2*r*math.pi
print(s)
print(c)
# Out:
#  3
# 28.274333882308138
# 18.84955592153876

# %%
import math

a = int(input())
b = int(input())
c = int(input())

p = (a + b + c) / 2
s = math.sqrt(p * (p - a) * (p - b) * (p - c))

if a == b == c:
    print("Là tam giác đều")
elif a == b or b == c or c == a:
    print("Là tam giác cân")
elif a**2 == b**2 + c**2 or b**2 == a**2 + c**2 or c**2 == a**2 + b**2:
    print("Là tam giác vuông")
elif a + b > c and a + c > b and b + c > a:
    print("Là tam giác thường")
else:
    print("Không là 3 cạnh của tam giác")

print("Diện tích:", s)
print("Chu vi:", p * 2)
# Out:
#  2
#  2
#  2
# Là tam giác đều
# Diện tích: 1.7320508075688772
# Chu vi: 6.0

# %%
a=int(input())
b=int(input())
if b==0:
    print("PT co vo so nghiem")
if a==0 and b!=0:
    print("PT vo nghiem")
if a!=0 and b!=0:
    x=-b/a
    print("PT co nghiem" ,x)
# Out:
#  3
#  6
# PT co nghiem -2.0

# %%
import math
a=int(input())
b=int(input())
c=int(input())
delta=b*b-4*a*c
if delta<0:
    print("PT vo nghiem")
if delta==0:
    x=-b/(2*a)
    print("PT co nghiem kep",x)
if delta>0:
    x1=(-b + math.sqrt(delta))/2*a
    x2=(-b - math.sqrt(delta))/2*a
    print("PT co 2 nghiem",x1,x2)
# Out:
#  1
#  -4
#  3
# PT co 2 nghiem 3.0 1.0

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
m=a 
if b>m:
    m=b
if c>m:
    m=c
if d>m:
    m=d
print(m)
# Out:
#  2
#  9
#  1
#  4
# 9

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
m=a 
if b<m:
    m=b
if c<m:
    m=c
if d<m:
    m=d
print(m)
# Out:
#  4
#  1
#  2
#  8
# 1

# %%
a=int(input())
gio=a//3600
phut=(a%3600)//60
giay=a-60*(gio*60+phut)
print(gio,"Giờ",phut,"Phút",giay,"Giây")
# Out:
#  8888
# 2 Giờ 28 Phút 8 Giây
